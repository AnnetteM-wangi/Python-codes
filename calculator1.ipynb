# %% [markdown]
# <a href="https://colab.research.google.com/github/AnnetteM-wangi/Python-codes/blob/main/calculator1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
def add(a,b):return a+b
def subtract(a,b):return a-b
def multiply(a,b):return a*b
def divide(a,b):
  if b==0:
    return "Error:divide by zero"
  return a/b
def calculator():
  print("Simple Calculator")
  print("Operators:+,-,*,/")
  while True:
    try:
     a=float(input("\nEnter first number:"))
     op=input("Enter operator (+,-,*,/):")
     b=float(input("Enter second number:"))

     if op=='+': print(f"Result:{add(a,b)}")
     elif op=='-':print(f"Result:{subtract(a,b)}")
     elif op=='*':print(f"Result:{multiply(a,b)}")
     elif op=='/':print(f"Result:{divide(a,b)}")
     else:print("invalid operator")
    except ValueError:
      print("please enter valid numbers")
    if input("\nCalculate again? (y/n):").lower() !='y':
      break
calculator()
# Out:
# Simple Calculator
# Operators:+,-,*,/
#
# Enter first number:25
# Enter operator (+,-,*,/):/
# Enter second number:5
# Result:5.0
#
# Calculate again? (y/n):n
